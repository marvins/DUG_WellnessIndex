# %% [markdown]
# (Part2_Initial_Reprojections)=
# # Part 2: Initial Reprojections
#
# ```{tableofcontents}
# ```
#
# This notebook focuses on taking all major inputs and reprojecting and clipping them to the same region of interest.  Most importantly, everything is reprojected to EPSG 32613, which is the UTM Grid Zone for Denver.
#
# As usual, I'm totally hacking here, so please forgive my terrible habits.
#
# ## General Outline
#
# 1. Import Packages
# 2. Load configuration data
# 3. Parse collection folder for every collect ID.
#    1. Verify pathname is valid ID, then parse components
#    2. Check what files exist
# 4. Reproject all Landsat images to EPSG 32613 and crop to ROI

# %% [markdown]
# ## Step 1: Import Required Packages

# %%
import configparser, datetime, logging, os, sys, time
from pyproj import CRS, Transformer
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

import rasterio
from rasterio.plot import show, show_hist
from rasterio.windows import Window

from tqdm import notebook as tqdm

from skimage import exposure

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#  DUG API
sys.path.insert(0,'..')
import dug_api.coordinate as dug_crd
import dug_api.imagery as dug_img
from dug_api.CollectID import CollectID, FileType
import dug_api.config as dug_cfg
import dug_api.wms as dug_wms

# %% [markdown]
# **Note:** If this flag is set to `True`, then no images will be written if a file already exists at the path.

# %%
skip_write_if_exists = True
update_if_duplicate  = False
filter_rasterio_logs = True

# %% [markdown]
# Setup logger.  If you are debugging, use `logging.DEBUG` rather than `logging.INFO`.

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger('Notebook')
logger.info( f'This Notebook run at {datetime.datetime.now().strftime("%Y:%m:%d %H:%M:%S")}' )
if filter_rasterio_logs:
    logging.getLogger('rasterio').setLevel(logging.INFO)
    logging.getLogger('matplotlib').setLevel(logging.INFO)

pd.set_option('display.max_colwidth', None)
# Out:
# INFO:Notebook:This Notebook run at 2024:01:05 15:02:51

# %% [markdown]
# ### Note to User
#
# Given the quirks of Jupyter-Book in generating this webpage, an environment variable is utilized to allow skipping modifying the database.  This is done so the CM version, built on my own machine, can be used without modification.

# %% [markdown]
# ## Step 2:  Loading Configuration Data
#
# I've done this long enough to know that any defined variable which is math or coordinate related needs to be in a configuration file.   This project includes `options.cfg`, which stores all settings for this project.

# %%
config = Configuration( '../data/options.cfg' )
logger.info( f'Is Configuration Valid:  {config.is_valid()}' )
# Out:
# INFO:Notebook:Is Configuration Valid:  True

# %% [markdown]
# We need to define the region we wish to process.  Not every image is guaranteed to be at the same projection, with the same footprint.  This means we need a globally defined bounding box, plus coordinate reference system (CRS).

# %%
logger.info( f'Output EPSG Code: {config.get_output_epsg()}' )
# Out:
# INFO:Notebook:Output EPSG Code: 32613

# %% [markdown]
# An EPSG code 32613 means a Universal Transverse Mercator projection (326) centered on Grid Zone 13.
# ```{figure} ../images/grid_zones.png
# :name: utm_zones
# :alt: Standard UTM Grid Zones
# :class: bg-primary mb-1
# :width: 80%
# :align: center
# ```

# %% [markdown]
# ## Step 3:  Build Initial Collection List
#
# Given the coordinate information, we can start finding imagery datasets.
#
# We have a directory listed with all the collections provided.

# %%
collection_dir = config.get_image_collection_path()
folder_list = [ x[0] for x in os.walk( collection_dir )][1:]
folder_list = list(filter( lambda x: '.git' not in x, folder_list ))
logger.info( f'Located {len(folder_list)} possible collection folders.' )
pd.DataFrame( { 'folders': folder_list } ).head(5)
# Out:
# INFO:Notebook:Located 1481 possible collection folders.
#                                                                                     folders
# 0             /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02
# 1           /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090822_20200911_02
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090822_20200911_02/gap_mask
# 3           /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02
# 4  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02/gap_mask

# %% [markdown]
# Landsat collections have a very specific naming structure.  See {cite}`landsat_ard_ctrl_book_2023`.
#
#
# ```{figure} ../images/naming_conventions.png
# :name: LS_L1TP_naming
# :alt: Landsat Level 1 Collection Product Naming
# :class: bg-primary mb-1
# :width: 80%
# :align: center
# ```
#
# ```{figure} ../images/ard_naming_conventions.png
# :name: LS_ARD_naming
# :alt: Landsat ARD Product Naming
# :class: bg-primary mb-1
# :width: 80%
# :align: center
# ```
#
# This is a figure from page 32.
#
# Now we can take the folders and verify which ones have valid collection IDs.  For this, we have the `CollectID` class in the `dug_api` package.

# %%
valid_cids = []
for folder in folder_list:

    cid = CollectID.from_pathname( folder )
    if cid != None:
        valid_cids.append( cid )
new_df = CollectID.list_to_dataframes( valid_cids )
new_df.head(5)
# Out:
#                                                                           pathname  \
# 0    /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02
# 1  /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090822_20200911_02
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02
# 4  /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090502_20200912_02
#
#                                      cid sensor  satellite product_type  \
# 0    LE07_CU_012009_20130529_20210501_02      E          7          ARD
# 1  LE07_L1GT_033033_20090822_20200911_02      E          7         L1GT
# 2  LE07_L1TP_033032_20130105_20200908_02      E          7         L1TP
# 3  LE07_L1TP_033033_20090110_20200912_02      E          7         L1TP
# 4  LE07_L1GT_033033_20090502_20200912_02      E          7         L1GT
#
#   processing_level  wrs2_path  wrs2_row  ard_col  ard_row  ...  \
# 0           ARD_CU        NaN       NaN     12.0      9.0  ...
# 1             L1GT       33.0      33.0      NaN      NaN  ...
# 2             L1TP       33.0      32.0      NaN      NaN  ...
# 3             L1TP       33.0      33.0      NaN      NaN  ...
# 4             L1GT       33.0      33.0      NaN      NaN  ...
#
#                                                                                                                            B7_path  \
# 0                                                                                                                             None
# 1                                                                                                                             None
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02/LE07_L1TP_033032_20130105_20200908_02_T1_B7.TIF
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02/LE07_L1TP_033033_20090110_20200912_02_T1_B7.TIF
# 4                                                                                                                             None
#
#   B8_path B9_path  \
# 0    None    None
# 1    None    None
# 2    None    None
# 3    None    None
# 4    None    None
#
#                                                                                                                                  B10_path  \
# 0                                                                                                                                    None
# 1                                                                                                                                    None
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02/LE07_L1TP_033032_20130105_20200908_02_T1_B6_VCID_2.TIF
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02/LE07_L1TP_033033_20090110_20200912_02_T1_B6_VCID_2.TIF
# 4                                                                                                                                    None
#
#   B11_path  \
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
#                                                                                                                     BT_B6_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_BT_B6.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
#                                                                                                                     ST_B6_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_B6.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
#                                                                                                                     ST_CDIST_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_CDIST.TIF
# 1                                                                                                                            None
# 2                                                                                                                            None
# 3                                                                                                                            None
# 4                                                                                                                            None
#
#                                                                                                                     ST_EMIS_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_EMIS.TIF
# 1                                                                                                                           None
# 2                                                                                                                           None
# 3                                                                                                                           None
# 4                                                                                                                           None
#
#                                                                                                                     ST_QA_path
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_QA.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
# [5 rows x 29 columns]

# %% [markdown]
# Now we need to join the tables and update the database

# %%
collection_df = config.update_table( 'collection_list', new_df, update_file=True )  
collection_df.head(5)
# Out:
#                                                                           pathname  \
# 0    /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02
# 1  /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090822_20200911_02
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02
# 4  /Volumes/data/imagery/Landsat/collections/LE07_L1GT_033033_20090502_20200912_02
#
#                                      cid sensor  satellite product_type  \
# 0    LE07_CU_012009_20130529_20210501_02      E          7          ARD
# 1  LE07_L1GT_033033_20090822_20200911_02      E          7         L1GT
# 2  LE07_L1TP_033032_20130105_20200908_02      E          7         L1TP
# 3  LE07_L1TP_033033_20090110_20200912_02      E          7         L1TP
# 4  LE07_L1GT_033033_20090502_20200912_02      E          7         L1GT
#
#   processing_level  wrs2_path  wrs2_row  ard_col  ard_row  ...  \
# 0           ARD_CU        NaN       NaN     12.0      9.0  ...
# 1             L1GT       33.0      33.0      NaN      NaN  ...
# 2             L1TP       33.0      32.0      NaN      NaN  ...
# 3             L1TP       33.0      33.0      NaN      NaN  ...
# 4             L1GT       33.0      33.0      NaN      NaN  ...
#
#                                                                                                                            B7_path  \
# 0                                                                                                                             None
# 1                                                                                                                             None
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02/LE07_L1TP_033032_20130105_20200908_02_T1_B7.TIF
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02/LE07_L1TP_033033_20090110_20200912_02_T1_B7.TIF
# 4                                                                                                                             None
#
#   B8_path B9_path  \
# 0    None    None
# 1    None    None
# 2    None    None
# 3    None    None
# 4    None    None
#
#                                                                                                                                  B10_path  \
# 0                                                                                                                                    None
# 1                                                                                                                                    None
# 2  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033032_20130105_20200908_02/LE07_L1TP_033032_20130105_20200908_02_T1_B6_VCID_2.TIF
# 3  /Volumes/data/imagery/Landsat/collections/LE07_L1TP_033033_20090110_20200912_02/LE07_L1TP_033033_20090110_20200912_02_T1_B6_VCID_2.TIF
# 4                                                                                                                                    None
#
#   B11_path  \
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
#                                                                                                                     BT_B6_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_BT_B6.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
#                                                                                                                     ST_B6_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_B6.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
#                                                                                                                     ST_CDIST_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_CDIST.TIF
# 1                                                                                                                            None
# 2                                                                                                                            None
# 3                                                                                                                            None
# 4                                                                                                                            None
#
#                                                                                                                     ST_EMIS_path  \
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_EMIS.TIF
# 1                                                                                                                           None
# 2                                                                                                                           None
# 3                                                                                                                           None
# 4                                                                                                                           None
#
#                                                                                                                     ST_QA_path
# 0  /Volumes/data/imagery/Landsat/collections/LE07_CU_012009_20130529_20210501_02/LE07_CU_012009_20130529_20210501_02_ST_QA.TIF
# 1                                                                                                                         None
# 2                                                                                                                         None
# 3                                                                                                                         None
# 4                                                                                                                         None
#
# [5 rows x 29 columns]

# %%
collection_df.loc[collection_df['cid'] == 'LC09_L1TP_034032_20230516_20230517_02_T1']
# Out:
# Empty DataFrame
# Columns: [pathname, cid, sensor, satellite, product_type, processing_level, wrs2_path, wrs2_row, ard_col, ard_row, acquisition_date, production_date, ANG_path, B1_path, B2_path, B3_path, B4_path, B5_path, B6_path, B7_path, B8_path, B9_path, B10_path, B11_path, BT_B6_path, ST_B6_path, ST_CDIST_path, ST_EMIS_path, ST_QA_path]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ### Setup Landsat Config Files

# %%
for cr in config.ls_collection_df.itertuples():
    logger.debug( f'Testing CID: {cr.cid}' )
    cid_config = config.get_ls_collection_config( cr.cid )

    #  make sure a few key fields are there
    assert( cid_config.has_option('general','cid') )
    assert( cid_config.has_option('general','pathname') )
# Out:
# INFO:root:Building new ls config for cid: 0    LE07_CU_012009_20130529_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1    LE07_L1GT_033033_20090822_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 2    LE07_L1TP_033032_20130105_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 3    LE07_L1TP_033033_20090110_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 4    LE07_L1GT_033033_20090502_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 5    LE07_CU_011009_20120906_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 6    LE07_L1TP_033033_20121017_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 7    LE07_CU_012009_20080727_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 8    LE07_CU_011009_20110927_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 9    LE07_L1TP_034032_20130128_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 10    LC09_CU_012009_20230423_20230502_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 11    LE07_CU_011009_20130409_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 12    LE07_CU_011009_20110522_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 13    LE07_CU_011009_20130326_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 14    LE07_CU_011009_20070723_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 15    LE07_CU_011009_20091228_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 16    LC09_L1TP_033032_20230712_20230713_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 17    LE07_CU_011009_20080427_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 18    LC09_CU_011009_20230601_20230606_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 19    LE07_L1TP_033032_20111015_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 20    LE07_CU_011009_20080709_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 21    LE07_CU_011009_20100309_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 22    LE07_CU_011009_20120227_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 23    LE07_CU_011009_20130418_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 24    LE07_CU_011009_20110305_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 25    LE07_L1TP_033032_20120830_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 26    LE07_L1TP_033033_20100926_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 27    LE07_CU_012009_20131105_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 28    LE07_L1TP_033032_20110305_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 29    LE07_CU_012009_20080506_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 30    LE07_CU_011009_20100214_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 31    LE07_CU_012009_20070427_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 32    LE07_L1GT_033032_20090502_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 33    LE07_CU_012009_20130709_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 34    LE07_L1TP_033032_20101113_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 35    LC09_L2SP_033032_20230813_20230815_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 36    LE07_CU_011009_20111116_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 37    LE07_L1TP_033033_20140430_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 38    LE07_CU_012009_20130623_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 39    LC09_L1TP_033033_20230306_20230307_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 40    LE07_CU_012009_20070506_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 41    LE07_CU_011009_20121116_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 42    LE07_L1TP_033032_20140124_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 43    LE07_L1TP_033033_20120424_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 44    LE07_L1TP_033033_20090705_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 45    LE07_L1TP_033033_20110406_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 46    LE07_CU_011009_20080312_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 47    LE07_L1TP_033032_20091025_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 48    LE07_L1TP_034032_20120720_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 49    LC08_CU_012009_20231008_20231021_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 50    LE07_CU_011009_20071221_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 51    LE07_L1TP_033033_20100521_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 52    LE07_CU_011009_20090719_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 53    LE07_CU_012009_20120323_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 54    LE07_CU_011009_20120812_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 55    LE07_L1TP_033032_20110727_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 56    LE07_CU_012009_20100622_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 57    LE07_CU_011009_20100731_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 58    LE07_L1TP_034032_20111209_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 59    LE07_L1GT_033032_20110524_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 60    LE07_CU_012009_20130105_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 61    LE07_CU_011009_20121211_20220224_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 62    LE07_L1GT_033033_20131004_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 63    LC09_L1TP_033032_20231016_20231016_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 64    LE07_CU_012009_20130810_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 65    LE07_CU_011009_20091124_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 66    LE07_L1GT_033033_20090923_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 67    LE07_CU_011009_20100127_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 68    LE07_L1TP_033033_20130801_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 69    LE07_L1TP_034032_20121227_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 70    LE07_CU_011009_20090626_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 71    LE07_L1TP_033033_20110201_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 72    LE07_CU_012009_20130213_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 73    LE07_CU_011009_20110625_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 74    LE07_CU_011009_20101003_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 75    LE07_CU_011009_20090416_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 76    LE07_CU_011009_20120220_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 77    LE07_L1TP_033033_20110828_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 78    LE07_CU_011009_20080207_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 79    LE07_CU_011009_20130213_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 80    LE07_CU_011009_20090806_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 81    LE07_CU_011009_20110810_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 82    LE07_L1GT_033032_20110116_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 83    LE07_L1TP_033032_20120627_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 84    LE07_L1TP_034032_20110312_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 85    LC09_CU_012009_20230610_20230615_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 86    LE07_CU_011009_20100410_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 87    LE07_CU_011009_20081207_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 88    LE07_CU_011009_20070716_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 89    LE07_L1TP_034032_20120922_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 90    LE07_L1TP_033033_20130310_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 91    LE07_CU_012009_20130801_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 92    LE07_CU_011009_20101222_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 93    LE07_L1TP_033033_20100129_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 94    LE07_CU_012009_20130301_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 95    LE07_L1TP_033032_20090806_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 96    LE07_CU_011009_20101213_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 97    LE07_L1TP_033032_20130902_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 98    LE07_CU_011009_20110303_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 99    LE07_L1TP_033033_20130222_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 100    LE07_L1TP_033033_20130529_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 101    LE07_L1TP_033033_20131207_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 102    LE07_CU_011009_20110616_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 103    LE07_CU_012009_20130927_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 104    LC09_CU_011009_20230703_20230708_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 105    LE07_L1TP_034032_20130723_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 106    LC08_CU_012009_20230602_20230611_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 107    LE07_CU_012009_20110328_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 108    LE07_CU_011009_20121109_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 109    LE07_CU_011009_20110812_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 110    LE07_L1TP_033033_20091009_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 111    LE07_CU_012009_20110226_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 112    LE07_CU_011009_20110319_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 113    LE07_CU_011009_20080413_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 114    LE07_L1TP_033033_20120204_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 115    LE07_L1TP_033033_20090227_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 116    LE07_CU_012009_20070808_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 117    LE07_L1TP_033032_20090227_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 118    LE07_L1TP_034032_20101120_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 119    LE07_CU_011009_20070128_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 120    LE07_CU_012009_20131112_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 121    LC08_L1TP_033032_20230906_20230912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 122    LE07_L1TP_033032_20110609_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 123    LE07_L1TP_033033_20130121_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 124    LE07_CU_011009_20070513_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 125    LE07_CU_011009_20120720_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 126    LE07_CU_011009_20100221_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 127    LE07_CU_011009_20110413_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 128    LE07_CU_011009_20130411_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 129    LE07_CU_011009_20070918_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 130    LE07_CU_011009_20080801_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 131    LE07_CU_011009_20101206_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 132    LE07_CU_011009_20071020_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 133    LE07_L1TP_034032_20130520_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 134    LE07_L1TP_033033_20090331_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 135    LE07_CU_011009_20070222_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 136    LE07_L1TP_034032_20130112_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 137    LE07_L1TP_034032_20100613_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 138    LE07_L1TP_033033_20130427_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 139    LE07_L1TP_033032_20140601_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 140    LE07_L1TP_034032_20110429_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 141    LE07_L1TP_033033_20121001_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 142    LE07_L1TP_034032_20100221_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 143    LC09_CU_012009_20230509_20230514_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 144    LE07_CU_011009_20061227_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 145    LE07_L1TP_034032_20140507_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 146    LE07_CU_012009_20070925_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 147    LE07_CU_011009_20120422_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 148    LC08_CU_012009_20230415_20230502_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 149    LC08_L2SP_034032_20230727_20230805_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 150    LC09_CU_012009_20230626_20230701_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 151    LE07_L1TP_034032_20121109_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 152    LE07_CU_012009_20081216_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 153    LE07_CU_011009_20080122_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 154    LE07_CU_012009_20081116_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 155    LE07_CU_011009_20070204_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 156    LE07_L1TP_033033_20121204_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 157    LE07_L1TP_033032_20120611_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 158    LE07_CU_012009_20120128_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 159    LE07_L1TP_033033_20110321_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 160    LC09_L1TP_033033_20230930_20230930_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 161    LE07_L1TP_033033_20120103_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 162    LE07_L1TP_033033_20110508_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 163    LC09_CU_012009_20230712_20230717_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 164    LE07_L1TP_034032_20100816_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 165    LE07_CU_012009_20110821_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 166    LE07_CU_011009_20070326_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 167    LE07_L1TP_034032_20090101_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 168    LC09_L1TP_033033_20230423_20230423_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 169    LE07_L1TP_033032_20111202_20210518_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 170    LC08_L1TP_033032_20231008_20231017_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 171    LE07_CU_011009_20090322_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 172    LE07_CU_012009_20070725_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 173    LE07_CU_012009_20071027_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 174    LE07_L1TP_034032_20100731_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 175    LE07_L1TP_033032_20120220_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 176    LE07_L1TP_034032_20130925_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 177    LE07_CU_011009_20130308_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 178    LE07_L1TP_033033_20120915_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 179    LE07_CU_011009_20090703_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 180    LE07_CU_011009_20090601_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 181    LE07_CU_011009_20071011_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 182    LE07_CU_011009_20080531_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 183    LE07_L1TP_033033_20101215_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 184    LE07_CU_011009_20090117_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 185    LE07_CU_012009_20131027_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 186    LE07_CU_012009_20080515_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 187    LE07_CU_012009_20130824_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 188    LE07_L1TP_033033_20090806_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 189    LE07_CU_011009_20091203_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 190    LE07_CU_012009_20120211_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 191    LE07_CU_011009_20120305_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 192    LE07_L1TP_034032_20130418_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 193    LE07_CU_011009_20101113_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 194    LE07_CU_011009_20090518_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 195    LE07_CU_011009_20120307_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 196    LE07_L1TP_033032_20130614_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 197    LE07_L1GT_033032_20090923_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 198    LE07_L1TP_033032_20120323_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 199    LC09_L1TP_033033_20230712_20230713_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 200    LE07_CU_011009_20130317_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 201    LE07_L1TP_033033_20130206_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 202    LE07_L1TP_034032_20090610_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 203    LE07_CU_011009_20081006_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 204    LC08_L1TP_033033_20230602_20230607_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 205    LE07_L1TP_033033_20121102_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 206    LE07_CU_011009_20120204_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 207    LC09_CU_011009_20230516_20230521_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 208    LE07_CU_011009_20110506_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 209    LE07_CU_012009_20130522_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 210    LE07_CU_011009_20100505_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 211    LC09_L1TP_033032_20230930_20230930_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 212    LE07_CU_011009_20120406_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 213    LE07_CU_012009_20071114_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 214    LE07_CU_012009_20070130_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 215    LE07_L1TP_033032_20121118_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 216    LE07_L1TP_033032_20120103_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 217    LE07_L1TP_033032_20110406_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 218    LC08_L1TP_033032_20230109_20230124_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 219    LE07_CU_011009_20100917_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 220    LE07_L1TP_033032_20121220_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 221    LE07_CU_011009_20130204_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 222    LE07_CU_012009_20130918_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 223    LE07_L1TP_033033_20110609_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 224    LE07_CU_011009_20080319_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 225    LC08_L1TP_033032_20230501_20230509_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 226    LE07_CU_011009_20111013_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 227    LE07_CU_011009_20090407_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 228    LE07_L1TP_034032_20131112_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 229    LE07_L1GT_033032_20140209_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 230    LE07_L1TP_033033_20100622_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 231    LE07_L1TP_034032_20090712_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 232    LE07_L1TP_033032_20140329_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 233    LE07_CU_011009_20121001_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 234    LE07_CU_011009_20080718_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 235    LE07_L1TP_033032_20120510_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 236    LE07_CU_011009_20080506_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 237    LE07_L1GT_033033_20120814_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 238    LE07_CU_011009_20131205_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 239    LE07_CU_011009_20111006_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 240    LE07_CU_011009_20121118_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 241    LE07_L1GT_033033_20110524_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 242    LC08_CU_012009_20230611_20230618_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 243    LE07_CU_011009_20090921_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 244    LE07_CU_011009_20121218_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 245    LE07_CU_012009_20131114_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 246    LE07_CU_011009_20090227_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 247    LE07_L1TP_034032_20120821_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 248    LE07_CU_012009_20081015_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 249    LE07_CU_011009_20090101_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 250    LC09_L1TP_033032_20230407_20230407_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 251    LE07_CU_011009_20070103_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 252    LE07_CU_011009_20080216_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 253    LE07_L1TP_034032_20110328_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 254    LE07_L1TP_034032_20100629_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 255    LE07_CU_011009_20110702_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 256    LE07_L1TP_034032_20140131_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 257    LE07_CU_011009_20120729_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 258    LE07_L1TP_033033_20110217_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 259    LE07_L1TP_033032_20100129_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 260    LE07_CU_011009_20100706_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 261    LE07_L1TP_034032_20110224_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 262    LE07_CU_011009_20070925_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 263    LE07_L1TP_034032_20100917_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 264    LE07_L1TP_033032_20090315_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 265    LE07_L1TP_033032_20110625_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 266    LC09_CU_012009_20230525_20230605_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 267    LC08_L1TP_033032_20230602_20230607_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 268    LE07_CU_011009_20111022_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 269    LE07_CU_012009_20110515_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 270    LE07_L1TP_033032_20110812_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 271    LE07_CU_012009_20090423_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 272    LE07_CU_011009_20090525_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 273    LE07_CU_011009_20120119_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 274    LE07_CU_011009_20091110_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 275    LC09_CU_012009_20230518_20230523_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 276    LE07_CU_011009_20110422_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 277    LE07_L1TP_033033_20140313_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 278    LE07_CU_011009_20101104_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 279    LE07_L1TP_033032_20110321_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 280    LE07_L1TP_034032_20110208_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 281    LE07_L1TP_033032_20120119_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 282    LC09_CU_011009_20230804_20230809_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 283    LE07_L1TP_033032_20140313_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 284    LE07_CU_011009_20101012_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 285    LE07_CU_012009_20120229_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 286    LE07_CU_011009_20090610_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 287    LC08_L1TP_033033_20230805_20230812_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 288    LE07_L1TP_033033_20130918_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 289    LE07_L1TP_034032_20110123_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 290    LE07_CU_011009_20120526_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 291    LE07_L1TP_034032_20120330_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 292    LE07_L1TP_033033_20120713_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 293    LE07_L1TP_033033_20091025_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 294    LE07_L1TP_033032_20130918_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 295    LE07_CU_011009_20110406_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 296    LE07_CU_011009_20110828_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 297    LE07_CU_011009_20080404_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 298    LE07_CU_011009_20110709_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 299    LE07_L1TP_033032_20100302_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 300    LE07_L1TP_034032_20100512_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 301    LE07_CU_011009_20081209_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 302    LE07_L1GT_033032_20090416_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 303    LE07_CU_012009_20120314_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 304    LE07_L1TP_033032_20130801_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 305    LE07_CU_012009_20090509_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 306    LE07_CU_011009_20070817_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 307    LE07_L1TP_033033_20130326_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 308    LE07_CU_012009_20080904_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 309    LE07_L1TP_034032_20121008_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 310    LE07_CU_012009_20131207_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 311    LE07_L1TP_033032_20091110_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 312    LE07_CU_011009_20100708_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 313    LE07_L1TP_033032_20110711_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 314    LE07_L1TP_033032_20111218_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 315    LE07_L1TP_033033_20110422_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 316    LE07_L1TP_034032_20130213_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 317    LE07_L1TP_034032_20130808_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 318    LC08_L1TP_033033_20230314_20230321_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 319    LE07_CU_012009_20130206_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 320    LC09_CU_012009_20230407_20230412_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 321    LE07_CU_011009_20100129_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 322    LE07_L1TP_034032_20100205_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 323    LE07_CU_011009_20110531_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 324    LE07_L1GT_033032_20100708_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 325    LE07_CU_012009_20130605_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 326    LE07_CU_011009_20090110_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 327    LC08_CU_012009_20230821_20230829_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 328    LE07_CU_012009_20110531_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 329    LC08_L1TP_033033_20230618_20230623_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 330    LE07_CU_011009_20101111_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 331    LE07_CU_011009_20080513_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 332    LE07_L1TP_034032_20140608_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 333    LE07_CU_011009_20070418_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 334    LE07_CU_012009_20130716_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 335    LE07_L1TP_033033_20120526_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 336    LE07_CU_011009_20091219_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 337    LE07_L1TP_033032_20090331_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 338    LE07_CU_011009_20120101_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 339    LE07_CU_011009_20121015_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 340    LE07_L1TP_034032_20110702_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 341    LE07_CU_011009_20110803_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 342    LE07_CU_011009_20111015_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 343    LE07_CU_011009_20071230_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 344    LE07_CU_011009_20110130_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 345    LE07_L1TP_033033_20130513_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 346    LE07_CU_011009_20090414_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 347    LE07_L1TP_034032_20130317_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 348    LE07_CU_011009_20101231_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 349    LE07_CU_011009_20111031_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 350    LC09_L1TP_033033_20230626_20230627_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 351    LE07_CU_011009_20080115_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 352    LE07_CU_011009_20070529_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 353    LC08_CU_012009_20230330_20230410_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 354    LC09_CU_011009_20230930_20231005_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 355    LE07_L1TP_033033_20120729_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 356    LE07_L1TP_033033_20100302_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 357    LE07_CU_011009_20120609_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 358    LE07_CU_011009_20091016_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 359    LE07_CU_012009_20070504_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 360    LE07_CU_012009_20070614_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 361    LC08_L2SP_033033_20230720_20230803_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 362    LE07_CU_011009_20111130_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 363    LE07_CU_012009_20110812_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 364    LE07_CU_011009_20130121_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 365    LE07_CU_011009_20110208_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 366    LE07_CU_011009_20130222_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 367    LE07_CU_011009_20070317_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 368    LE07_CU_012009_20131020_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 369    LE07_L1TP_033032_20090619_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 370    LE07_CU_011009_20111123_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 371    LE07_CU_011009_20090603_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 372    LE07_L1TP_034032_20090306_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 373    LE07_L1TP_034032_20091117_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 374    LE07_L1GT_033033_20110116_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 375    LE07_CU_012009_20131214_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 376    LE07_L1TP_034032_20140710_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 377    LE07_L1TP_034032_20100309_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 378    LE07_CU_011009_20080918_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 379    LC09_CU_011009_20231007_20231011_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 380    LE07_CU_011009_20110819_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 381    LE07_CU_011009_20071128_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 382    LE07_L1TP_033032_20120204_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 383    LE07_L1TP_034032_20110803_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 384    LE07_CU_012009_20090416_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 385    LE07_CU_011009_20110321_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 386    LE07_CU_011009_20080716_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 387    LE07_L1TP_034032_20091203_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 388    LE07_CU_012009_20081013_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 389    LE07_CU_011009_20130128_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 390    LC09_L1TP_033033_20230525_20230525_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 391    LE07_L1TP_033033_20090315_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 392    LE07_CU_012009_20120204_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 393    LE07_CU_012009_20110413_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 394    LE07_L1TP_033033_20090619_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 395    LE07_CU_012009_20070317_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 396    LE07_L1TP_033032_20101215_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 397    LE07_CU_012009_20120220_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 398    LE07_CU_012009_20091126_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 399    LE07_L1TP_033033_20090126_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 400    LE07_CU_012009_20070605_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 401    LE07_CU_011009_20110718_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 402    LC09_L1TP_033033_20230829_20230830_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 403    LE07_CU_011009_20120408_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 404    LE07_L1TP_033033_20101028_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 405    LE07_CU_011009_20101019_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 406    LE07_CU_011009_20070301_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 407    LE07_CU_012009_20080718_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 408    LE07_CU_011009_20120202_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 409    LE07_CU_011009_20100419_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 410    LE07_CU_011009_20080328_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 411    LE07_CU_012009_20070621_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 412    LE07_CU_011009_20080223_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 413    LE07_L1TP_034032_20120704_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 414    LE07_L1TP_033032_20121102_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 415    LC09_L1TP_033032_20230525_20230525_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 416    LE07_CU_011009_20110609_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 417    LE07_CU_011009_20130402_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 418    LE07_CU_011009_20080225_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 419    LE07_CU_011009_20070402_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 420    LE07_CU_011009_20110224_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 421    LE07_L1TP_034032_20091016_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 422    LE07_CU_011009_20100715_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 423    LE07_L1TP_034032_20091219_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 424    LE07_CU_012009_20080131_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 425    LE07_CU_011009_20090930_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 426    LE07_CU_011009_20101010_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 427    LE07_CU_011009_20080725_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 428    LE07_CU_011009_20070206_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 429    LE07_CU_012009_20090721_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 430    LE07_CU_012009_20130707_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 431    LE07_L1TP_033032_20090211_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 432    LE07_L1TP_034032_20130504_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 433    LE07_L1TP_033032_20120915_20200908_02
# Name: cid, dtype: object
# ...
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 944    LE07_L1TP_034032_20110616_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 945    LE07_L1TP_034032_20130824_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 946    LE07_CU_011009_20120611_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 947    LE07_CU_011009_20070511_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 948    LE07_L1TP_033033_20110727_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 949    LE07_L1TP_034032_20121211_20210519_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 950    LE07_CU_012009_20080524_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 951    LE07_CU_011009_20100809_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 952    LE07_CU_011009_20110904_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 953    LE07_L1TP_033033_20120611_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 954    LE07_CU_012009_20070520_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 955    LE07_CU_012009_20101019_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 956    LE07_L1TP_033032_20091126_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 957    LE07_L1GT_033033_20101012_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 958    LE07_CU_011009_20080131_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 959    LE07_L1TP_033033_20111218_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 960    LE07_CU_011009_20070409_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 961    LE07_CU_011009_20081225_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 962    LE07_CU_011009_20100724_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 963    LE07_CU_012009_20070623_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 964    LE07_CU_011009_20100823_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 965    LE07_CU_012009_20090518_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 966    LE07_L1TP_034032_20131011_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 967    LC09_L1TP_033033_20230728_20230804_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 968    LC09_CU_012009_20230829_20230903_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 969    LE07_CU_011009_20081013_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 970    LE07_CU_012009_20130621_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 971    LE07_L1GT_033032_20101231_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 972    LE07_CU_011009_20080616_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 973    LE07_CU_011009_20120330_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 974    LE07_CU_011009_20080106_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 975    LE07_L1TP_033032_20110913_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 976    LE07_L1TP_033033_20110305_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 977    LE07_CU_011009_20120805_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 978    LE07_CU_011009_20111107_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 979    LE07_CU_012009_20070716_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 980    LE07_CU_011009_20080623_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 981    LE07_CU_011009_20081114_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 982    LE07_L1TP_033032_20110508_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 983    LE07_CU_011009_20110911_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 984    LE07_CU_012009_20110727_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 985    LE07_L1TP_034032_20140405_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 986    LC09_CU_012009_20230907_20230916_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 987    LE07_L1TP_033032_20090705_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 988    LC09_CU_012009_20230728_20230807_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 989    LC08_L2SP_034032_20230828_20230906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 990    LC08_L1TP_033033_20230906_20230912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 991    LE07_CU_011009_20080702_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 992    LE07_L1TP_033032_20130513_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 993    LE07_CU_012009_20130128_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 994    LE07_L1TP_033032_20110929_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 995    LE07_L1TP_033033_20100505_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 996    LE07_CU_011009_20130310_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 997    LE07_L1TP_034032_20110413_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 998    LE07_L1TP_033033_20101231_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 999    LE07_CU_011009_20120517_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1000    LE07_CU_012009_20130607_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1001    LE07_CU_012009_20080609_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1002    LE07_CU_011009_20090721_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1003    LE07_L1TP_033033_20140124_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1004    LE07_CU_012009_20120908_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1005    LE07_L1GT_130211_20140524_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1006    LE07_CU_011009_20090509_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1007    LE07_CU_011009_20100528_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1008    LE07_CU_011009_20110725_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1009    LC09_L2SP_033033_20230525_20230601_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1010    LE07_L1TP_033033_20130411_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1011    LE07_CU_012009_20130925_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1012    LE07_CU_011009_20120103_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1013    LE07_CU_011009_20121017_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1014    LE07_CU_012009_20080305_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1015    LE07_CU_011009_20081123_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1016    LE07_CU_012009_20070513_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1017    LE07_CU_011009_20080826_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1018    LE07_CU_011009_20100228_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1019    LE07_CU_011009_20090705_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1020    LE07_L1TP_033033_20111015_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1021    LE07_CU_012009_20130513_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1022    LE07_L1GT_130212_20140524_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1023    LE07_CU_011009_20110217_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1024    LE07_CU_011009_20080810_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1025    LE07_L1TP_034032_20110515_20200910_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1026    LC08_L1TP_034032_20231202_20231209_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1027    LE07_L1TP_033032_20100521_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1028    LE07_CU_011009_20110123_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1029    LE07_CU_012009_20130427_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1030    LE07_CU_011009_20070310_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1031    LE07_L1TP_033032_20111116_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1032    LE07_CU_011009_20110623_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1033    LE07_CU_011009_20091226_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1034    LE07_CU_011009_20080920_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1035    LE07_L1TP_033032_20130206_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1036    LE07_L1TP_033033_20090518_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1037    LE07_CU_012009_20080927_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1038    LE07_CU_011009_20130511_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1039    LE07_CU_011009_20090914_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1040    LE07_CU_011009_20120524_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1041    LC09_L1TP_034032_20230516_20230517_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1042    LE07_CU_011009_20071103_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1043    LE07_CU_012009_20130723_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1044    LE07_CU_012009_20080108_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1045    LE07_CU_011009_20120713_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1046    LE07_CU_011009_20090124_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1047    LE07_L1TP_033033_20091212_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1048    LE07_CU_011009_20100629_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1049    LE07_CU_012009_20130826_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1050    LE07_CU_011009_20120602_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1051    LE07_L1TP_034032_20111022_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1052    LE07_L1TP_034032_20131128_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1053    LE07_CU_011009_20120508_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1054    LE07_CU_011009_20080326_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1055    LE07_L1TP_033032_20121017_20200908_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1056    LE07_CU_011009_20100316_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1057    LE07_CU_011009_20101026_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1058    LE07_CU_011009_20071223_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1059    LC08_CU_012009_20230618_20230626_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1060    LE07_CU_011009_20100512_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1061    LC09_L1TP_033032_20231101_20231101_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1062    LE07_L1TP_033033_20091110_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1063    LE07_CU_012009_20081218_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1064    LE07_L1TP_034032_20100410_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1065    LE07_CU_011009_20090306_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1066    LC08_L1TP_033032_20231024_20231031_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1067    LE07_CU_011009_20070808_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1068    LE07_CU_012009_20071004_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1069    LE07_L1TP_034032_20090423_20200912_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1070    LE07_L1GT_033032_20090822_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1071    LE07_L1TP_033032_20140617_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1072    LE07_L1TP_033033_20100214_20200911_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1073    LE07_CU_012009_20121213_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1074    LE07_L1TP_033033_20140703_20200906_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1075    LE07_CU_011009_20110508_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1076    LE07_CU_011009_20070112_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1077    LE07_L1TP_033032_20130630_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1078    LE07_L1TP_033033_20130716_20200907_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1079    LE07_CU_012009_20070420_20210429_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1080    LE07_CU_011009_20120117_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1081    LE07_CU_012009_20130222_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1082    LE07_CU_011009_20120627_20210501_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1083    LE07_CU_012009_20110415_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1084    LE07_CU_011009_20090423_20210430_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1085    LE07_L1TP_034032_20120126_20200909_02
# Name: cid, dtype: object
# INFO:root:Building new ls config for cid: 1086    LE07_L1TP_034032_20101206_20200910_02
# Name: cid, dtype: object

# %% [markdown]
# ## Step 4:  Reproject all relevant images
#
# As previously mentioned, Landsat data comes in different sizes, projections, and representations.  We need to reproject all images into the same coordinate system.

# %% [markdown]
# We need to get polygon points in UTM.
#
# The order in the config is `[[min x, min y]],[max x, max y]]`

# %%
bbox_utm = config.get_region()
logger.info( bbox_utm )
# Out:
# INFO:Notebook:[[462191.7886451932, 4357374.143059055], [547590.5223242528, 4450167.255409848]]
# Points: [[-105.438889, 39.365], [-104.440833, 40.200556]]

# %% [markdown]
# 1. Iterate over each collection.
# 2. Iterate over each file in the collection (`file_<key>`).
# 3. Get the reprojected path and see if it exists yet.

# %%
file_types_to_reproject = [ f'b{x}_path' for x in range( 1, 12 ) ]

# %%
entries = { 'Collect-ID': collection_df['cid'].unique() }
for f in file_types_to_reproject:
    entries[f] = ''

completed_rows = pd.DataFrame( entries )

# %%
dest_epsg = config.get_output_epsg()
dest_gsd  = config.get_output_gsd()

pbar_cid = tqdm.tqdm( total=collection_df.shape[0] )
cid_counter = 0

pbar_files = tqdm.tqdm( total = len(file_types_to_reproject) )
file_counter = 0

#  iterate over each row
for cr in config.ls_collection_df.itertuples():

    cr_dict = cr._asdict()
    cid = cr_dict['cid']

    #  Clear the progress bar
    pbar_files.reset()

    #  Get the collection configuration object to update
    cid_config = config.get_ls_collection_config( cid )
    
    #  iterate over each file we need to reproject
    for col in file_types_to_reproject:

        update_db = False
        
        #  Skip if the collection doesn't have the band
        if cid_config.has_option('general',col) == False:
            pbar_files.update( 1 )
            continue
        path_in  = cid_config.get('general',col)

        path_out_key = f'{col}_epsg_{dest_epsg}'
        if cid_config.has_option('general',path_out_key):
            path_out = cid_config.get('general',path_out_key)
        else:
            in_bname = os.path.splitext(os.path.basename( path_in ) )
            path_out = os.path.join( os.path.dirname( path_in ), f'{in_bname[0]}.epsg_{dest_epsg}{in_bname[1]}' )
            cid_config['general'][path_out_key] = path_out
            update_db = True

        # if there is no input path, simply skip it (Each dataset only has a subset of possible types)
        if path_in is None:
            pass

        #  This is slightly concerning.  This is the input path is defined, but not found.
        elif not os.path.exists( path_in ):
            raise Exception( f'Source image {path_in} does not exist.' )
        
        elif skip_write_if_exists and path_out != None and os.path.exists( path_out ):
            completed_rows.loc[completed_rows['Collect-ID'] == cid, col] = 'Skipped'
        
        else:
                                         
            # Reproject image
            dug_img.reproject_image( path_in  = path_in,
                                     path_out = path_out,
                                     epsg     = dest_epsg,
                                     bbox_utm = bbox_utm,
                                     dest_gsd = dest_gsd )

            #  Note where the new reprojected file is (Keep this indent level as this file even
            #  if the processing is skipped
            update_db = True
            
            completed_rows.loc[completed_rows['Collect-ID'] == cid, col] = 'Completed'

        #  Write intermediate results to disk
        if update_db:
            config.set_ls_collection_config( cid_config )

        pbar_files.update( 1 )
        
    pbar_cid.update( 1 )
# Out:
#   0%|          | 0/1087 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 56
#      51     completed_rows.loc[completed_rows['Collect-ID'] == cid, col] = 'Skipped'
#      53 else:
#      54
#      55     # Reproject image
# ---> 56     imagery.reproject_image( path_in  = path_in,
#      57                              path_out = path_out,
#      58                              epsg     = dest_epsg,
#      59                              bbox_utm = bbox_utm,
#      60                              dest_gsd = dest_gsd )
#      62     #  Note where the new reprojected file is (Keep this indent level as this file even
#      63     #  if the processing is skipped
#      64     update_db = True
#
# NameError: name 'imagery' is not defined

# %%
completed_rows

# %% [markdown]
# #  Visualizing Results

# %% [markdown]
# For this analysis, we'll use the City Lights Garden as our reference image.

# %%
garden_name = 'City Lights at Benedict Park Place Community Garden'

lon_key = 'Garden Geolocation (Longitude)'
lat_key = 'Garden Geolocation (Latitude)'

def get_garden():
    csv_path = '../data/GardenDataForMaps120623.xlsx'
    all_gardens_df = pd.read_excel( csv_path )
    garden_df = all_gardens_df.loc[all_gardens_df['Garden: Garden Name'] == garden_name]
    return garden_df

garden_df = get_garden()
assert( garden_df.shape[0] == 1 )
garden_df

# %% [markdown]
# #### NAIP
# The National Agriculture Image Program (NAIP) provides < 0.25 m GSD imagery for most of CONUS.  This is the highest-resolution and most up-to-date imagery you will find.

# %%
garden_ll = ( garden_df[lon_key].values[0],
              garden_df[lat_key].values[0] )

garden_roi = dug_crd.convert_coord_roi( center_coord       = garden_ll,
                                        input_epsg         = 4326,
                                        window_size_pixels = [800,800],
                                        dest_gsd           = 1,
                                        output_epsg        = config.get_output_epsg() )

# %%
wms_gsd = 1.0
wms_window_m = np.array( [600,600], np.float32 )
wms_window_pix = list(wms_window_m / wms_gsd)
wms_image = load_tile( base_url     = config.get('naip','wms_url'),
                       epsg         = config.get_output_epsg(),
                       center_ll    = garden_ll,
                       win_size_pix = wms_window_pix,
                       gsd          = wms_gsd,
                       layers       = [config.get('naip','wms_layers')],
                       format       = config.get('naip','wms_format') )
wms_image = np.transpose( wms_image, axes = [1, 2, 0 ] )[:,:,:3]

# %% [markdown]
# ## Landsat 7 and 8 Collections
#
# Landsat 7: `LE07_L1TP_033032_20130801_20200907_02_T1`
# Landsat 8: `LC08_L1TP_033032_20230805_20230812_02_T1`
#
# To visualize the imagery, we load the Blue, Green, and Red bands. For plotting, I recommend using `rasterio.plot` in memory-intensive applications as well as test applications.  It's not the prettiest, such as plotly, but it works really efficiently.  See [link](https://rasterio.readthedocs.io/en/stable/topics/plotting.html) for examples.

# %%
analysis_cid7 = 'LE07_L1TP_033032_20130801_20200907_02_T1'
analysis_cid8 = 'LC08_L1TP_033032_20230805_20230812_02_T1'

# %%
def load_and_merge_frames( cid, bands, roi, epsg, equalize = False, perform_transpose=False ):

    cid_config = config.get_ls_collection_config( cid )

    images = []
    for id in bands:

        key    = f'b{id}_path_epsg_{epsg}'
        driver = rasterio.open( cid_config.get('general',key) )

        ls_window = dug_img.get_window_from_coords( roi[0], roi[1], epsg, driver )

        image = driver.read(1, window=ls_window)

        if driver.profile['dtype'] == 'uint16':
            image = np.clip( image.astype('uint16') / 128, 0, 255 )

        # https://stackoverflow.com/a/47398865/2142228
        if equalize:
            image = exposure.adjust_log( image, 1)
        images.append( image )

    output = np.dstack( images ).astype('uint8')
    if perform_transpose:
        output = np.transpose( output, axes=[0,1,2] )
        
    return output

# %%
ls7_rgb_image = load_and_merge_frames( analysis_cid7, [3,2,1], garden_roi, config.get_output_epsg(), True )
ls8_rgb_image = load_and_merge_frames( analysis_cid8, [4,3,2], garden_roi, config.get_output_epsg(), False )

fig_ov = make_subplots( rows=3, cols=2, 
                        subplot_titles=['NAIP',      'Histogram',
                                        'Landsat 7', 'Histogram',
                                        'Landsat 8', 'Histogram'], 
                        horizontal_spacing=0.05,
                        vertical_spacing=0.05,
                        column_widths=[0.5,0.5])

#  Add WMS Image
fig_ov.add_trace( go.Image( z = wms_image ), row=1, col=1 )
counts, bins = np.histogram( wms_image.flatten(), bins = 30 )
bins = 0.5 * (bins[:-1] + bins[1:])

fig_ov.add_trace( go.Scatter( x = bins,
                              y = counts,
                              name = 'NAIP' ), row = 1, col = 2 )

#  Add the Landsat 7 Image
fig_ov.add_trace( go.Image( z = ls7_rgb_image ), row=2, col=1 )
counts, bins = np.histogram( ls7_rgb_image.flatten(), bins = 30 )
bins = 0.5 * (bins[:-1] + bins[1:])

fig_ov.add_trace( go.Scatter( x = bins,
                              y = counts,
                              name = 'Landsat 7' ), row = 2, col = 2 )

#  Add the Landsat 9 Image
fig_ov.add_trace( go.Image( z = ls8_rgb_image ), row=3, col=1 )

counts, bins = np.histogram( ls8_rgb_image.flatten(), bins = 30 )
bins = 0.5 * (bins[:-1] + bins[1:])

fig_ov.add_trace( go.Scatter( x = bins,
                              y = counts,
                              name = 'Landsat 8' ), row = 3, col = 2 )

fig_ov.update_layout( width = 800,
                      height = 1200,
                      title  = 'Comparison of Landsat Imagery',
                      showlegend = False,
                      margin=dict(l=20, r=20, t=80, b=20, pad=2) )

fig_ov.update_xaxes(showticklabels=False)
fig_ov.update_yaxes(showticklabels=False)
fig_ov.show(renderer="svg")

# %% [markdown]
# As you can see, Landsat is pretty blurry with it's 30m Ground Sample Distance.
